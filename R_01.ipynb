# %% [markdown]
# # Load the libraries

# %%
library(data.table)
library(tidyverse)
# library(readr)
# library(RSQLite)
# library(sqldf)
# library(R.utils)
# library(progress)
# Out:
# -- Attaching core tidyverse packages -------------------------------------------------------------------------- tidyverse 2.0.0 --
# v dplyr     1.1.0     v readr     2.1.4
# v forcats   1.0.0     v stringr   1.5.0
# v ggplot2   3.4.2     v tibble    3.2.0
# v lubridate 1.9.2     v tidyr     1.3.0
# v purrr     1.0.1
# -- Conflicts -------------------------------------------------------------------------------------------- tidyverse_conflicts() --
# x dplyr::between()     masks data.table::between()
# x dplyr::filter()      masks stats::filter()
# x dplyr::first()       masks data.table::first()
# x purrr::flatten()     masks jsonlite::flatten()
# x lubridate::hour()    masks data.table::hour()
# x lubridate::isoweek() masks data.table::isoweek()
# x dplyr::lag()         masks stats::lag()
# x dplyr::last()        masks data.table::last()
# x lubridate::mday()    masks data.table::mday()
# x lubridate::minute()  masks data.table::minute()
# ...

# %% [markdown]
# # Load the dataframe with Accession IDs of sequences analysed by CoViD-19 CG

# %%
df1 <- read.csv("./raw_data/25_may_23/230525_kumar_file1.csv")

dim(df1)
head(df1)
# Out:
# [1] 12612203        7
#   collection_date         mutation_name mutation_str pos   ref alt count
# 1 2019-12-30 00:00:00.000 T104A         1|104|T|A      104 T   A   1
# 2 2019-12-30 00:00:00.000 A21137G       1|21137|A|G  21137 A   G   1
# 3 2019-12-30 00:00:00.000 G21316A       1|21316|G|A  21316 G   A   1
# 4 2019-12-30 00:00:00.000 T21656A       1|21656|T|A  21656 T   A   1
# 5 2019-12-30 00:00:00.000 A24325G       1|24325|A|G  24325 A   G   4
# 6 2020-01-01 00:00:00.000 C10078T       1|10078|C|T  10078 C   T   1

# %%
df2 <- read.csv("./raw_data/25_may_23/230525_kumar_file2.csv")

dim(df2)
colnames(df2) <- c("AccessionIDs", "CollectionDate")
head(df2)
# Out:
# [1] 97101     7
#   AccessionIDs CollectionDate <NA>  <NA> <NA> <NA>     <NA>
# 1 A23403G      1|23403|A|G    23403 A    G    11692133 1.829007
# 2 C3037T       1|3037|C|T      3037 C    T    11670729 1.825659
# 3 C14408T      1|14408|C|T    14408 C    T    11669447 1.825458
# 4 C241T        1|241|C|T        241 C    T    11499166 1.798821
# 5 C22995A      1|22995|C|A    22995 C    A     9139297 1.429666
# 6 C10029T      1|10029|C|T    10029 C    T     9106039 1.424463

# %%
print("Loading df3...")
df3 <- read.csv("./raw_data/25_may_23/230525_kumar_file3.csv")

dim(df3)
colnames(df3) <- c("AccessionIDs", "CollectionDate")
head(df3)
print("Loaded df3 successfully!")
# Out:
# [1] "Loading df3..."
# [1] 11740545        2
#   AccessionIDs   CollectionDate
# 1 EPI_ISL_402121 2019-12-30 00:00:00.000
# 2 EPI_ISL_402123 2019-12-24 00:00:00.000
# 3 EPI_ISL_402124 2019-12-30 00:00:00.000
# 4 EPI_ISL_402127 2019-12-30 00:00:00.000
# 5 EPI_ISL_402128 2019-12-30 00:00:00.000
# 6 EPI_ISL_402129 2019-12-30 00:00:00.000
# [1] "Loaded df3 successfully!"

# %% [markdown]
# # Load the complete metadata file

# %%
# print("Execution started...")

# # Specify the file paths
# metadata_file <- "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.tsv"
# output_file <- "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata_filtered.csv"

# # Read the metadata file using data.table's fread() function
# metadata_dt <- fread(metadata_file, sep = "\t", header = TRUE)

# print("Execution completed...")

# %% [markdown]
# # Subset metadata

# %%
# # ----------------------------------------------------------------------------
# # Subset Metadata ------------------------------------------------------------
# # ----------------------------------------------------------------------------

# print("Execution started...")

# # Load the accession IDs from the "df3" dataframe into a vector
# accession_ids <- df3$AccessionIDs

# # Filter the metadata based on the accession IDs
# metadata.filtered <- metadata_dt[`Accession ID` %in% accession_ids]

# # Save the filtered data as a CSV file
# write.csv(metadata.filtered, file = output_file, row.names = FALSE)
# saveRDS(metadata.filtered, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.filtered.rds")

# print("Execution completed...")

# %% [markdown]
# # Load the saved RDS object of filtered metadata

# %%
metadata.filtered <- readRDS("/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.filtered.rds")

# %%
dim(metadata.filtered)
colnames(metadata.filtered)
head(metadata.filtered)
# Out:
# [1] 11609119       24
#  [1] "Virus name"                      "Last vaccinated"
#  [3] "Passage details/history"         "Type"
#  [5] "Accession ID"                    "Collection date"
#  [7] "Location"                        "Additional location information"
#  [9] "Sequence length"                 "Host"
# [11] "Patient age"                     "Gender"
# [13] "Clade"                           "Pango lineage"
# [15] "Pango version"                   "Variant"
# [17] "AA Substitutions"                "Submission date"
# [19] "Is reference?"                   "Is complete?"
# [21] "Is high coverage?"               "Is low coverage?"
# [23] "N-Content"                       "GC-Content"
#   Virus name                              Last vaccinated
# 1 hCoV-19/England/MILK-3109B1B/2022
# 2 hCoV-19/USA/WI-WSLH-222668/2021
# 3 hCoV-19/England/MILK-30FD498/2022
# 4 hCoV-19/France/ARA-HCL021201855701/2021
# 5 hCoV-19/Germany/NW-RKI-I-433432/2022
# 6 hCoV-19/USA/CA-FS25406602/2021
# ...

# %%
df <- metadata.filtered

# %%
head(df)
# Out:
#   Virus name                              Last vaccinated
# 1 hCoV-19/England/MILK-3109B1B/2022
# 2 hCoV-19/USA/WI-WSLH-222668/2021
# 3 hCoV-19/England/MILK-30FD498/2022
# 4 hCoV-19/France/ARA-HCL021201855701/2021
# 5 hCoV-19/Germany/NW-RKI-I-433432/2022
# 6 hCoV-19/USA/CA-FS25406602/2021
#   Passage details/history Type            Accession ID    Collection date
# 1 Original                betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 Original                betacoronavirus EPI_ISL_9678637 2021-12-21
# 3 Original                betacoronavirus EPI_ISL_8532336 2022-01-03
# 4 Original                betacoronavirus EPI_ISL_6842886 2021-11-13
# 5 Original                betacoronavirus EPI_ISL_8682478 2022-01-11
# 6 Original                betacoronavirus EPI_ISL_4869788 2021-08-25
#   Location
# 1 Europe / United Kingdom / England
# 2 North America / USA / Wisconsin / Sheboygan County
# 3 Europe / United Kingdom / England
# 4 Europe / France / Auvergne-Rhone-Alpes
# ...

# %%
# print("Running...")
# # Assuming your original dataframe is named 'original_df'
# # You can create a new dataframe named 'new_df' to store the transformed data

# new_rows <- list()

# for (i in 1:nrow(original_df)) {
#   aa_substitutions <- unlist(strsplit(original_df$`AA Substitutions`[i], ","))
#   collection_date <- original_df$`Collection date`[i]
#   submission_date <- original_df$`Submission date`[i]
#   location <- original_df$Location[i]
#   virus_name <- original_df$`Virus name`[i]
  
#   for (aa_sub in aa_substitutions) {
#     new_rows <- c(new_rows, list(c(aa_sub, collection_date, submission_date, location, virus_name)))
#   }
# }

# new_df <- data.frame(do.call(rbind, new_rows))
# colnames(new_df) <- c("AA Substitution", "Collection date", "Submission date", "Location", "Virus name")

# # Print the resulting dataframe
# print(new_df)

# %%
colnames(df)
# Out:
#  [1] "Virus name"                      "Last vaccinated"
#  [3] "Passage details/history"         "Type"
#  [5] "Accession ID"                    "Collection date"
#  [7] "Location"                        "Additional location information"
#  [9] "Sequence length"                 "Host"
# [11] "Patient age"                     "Gender"
# [13] "Clade"                           "Pango lineage"
# [15] "Pango version"                   "Variant"
# [17] "AA Substitutions"                "Submission date"
# [19] "Is reference?"                   "Is complete?"
# [21] "Is high coverage?"               "Is low coverage?"
# [23] "N-Content"                       "GC-Content"

# %%
df$`AA Substitutions`[1]
# Out:
# [1] "(NSP5_P132H,Spike_H69del,Spike_T95I,Spike_A67V,Spike_S373P,Spike_Q493R,Spike_N969K,Spike_H655Y,Spike_N856K,N_R203K,Spike_G142D,NSP3_A1892T,Spike_Q954H,NS3_D155Y,N_P13L,NSP3_L1266I,Spike_N501Y,N_R32del,M_Q19E,NSP4_T492I,NSP6_L105del,Spike_N679K,Spike_N764K,Spike_L212I,NSP6_G107del,Spike_Y505H,NSP6_I189V,Spike_T547K,M_D3G,Spike_D796Y,N_G204R,Spike_T478K,Spike_V143del,M_A63T,Spike_G496S,NSP12_M110V,NSP6_S106del,Spike_S371L,Spike_G339D,NSP3_S1265del,NSP14_I42V,Spike_P681H,Spike_Y144del,Spike_ins214EPE,N_S33del,Spike_S375F,Spike_Q498R,NSP3_T1004I,Spike_S477N,N_E31del,NSP3_K38R,Spike_N211del,Spike_E484A,E_T9I,Spike_V70del,Spike_L981F,NSP12_P323L,Spike_D614G,Spike_Y145del)"

# %%
DF <- head(df)
DF
# Out:
#   Virus name                              Last vaccinated
# 1 hCoV-19/England/MILK-3109B1B/2022
# 2 hCoV-19/USA/WI-WSLH-222668/2021
# 3 hCoV-19/England/MILK-30FD498/2022
# 4 hCoV-19/France/ARA-HCL021201855701/2021
# 5 hCoV-19/Germany/NW-RKI-I-433432/2022
# 6 hCoV-19/USA/CA-FS25406602/2021
#   Passage details/history Type            Accession ID    Collection date
# 1 Original                betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 Original                betacoronavirus EPI_ISL_9678637 2021-12-21
# 3 Original                betacoronavirus EPI_ISL_8532336 2022-01-03
# 4 Original                betacoronavirus EPI_ISL_6842886 2021-11-13
# 5 Original                betacoronavirus EPI_ISL_8682478 2022-01-11
# 6 Original                betacoronavirus EPI_ISL_4869788 2021-08-25
#   Location
# 1 Europe / United Kingdom / England
# 2 North America / USA / Wisconsin / Sheboygan County
# 3 Europe / United Kingdom / England
# 4 Europe / France / Auvergne-Rhone-Alpes
# ...

# %%
stringManipulation <- function (x) {
    y <- str_remove_all(string = x, pattern = "[()]")
    print(class(y))
    y <- str_split(string = y, pattern = ",")
    print(class(y))
    return (y)
    # return (sum(sapply(y, length)))
}

# %%
# n.aaSubs <- lapply(df[, "AA Substitutions"], stringManipulation)
# n.aaSubs
# Output:  $`AA Substitutions` = 509825914
# n.aaSubs = 509825914

# %%
# for (row in 1:nrow(DF)) {
#     aaSubs <- DF[row, "AA Substitutions"]
#     aaSubs <- str_remove_all(string = aaSubs, pattern = "[()]")
#     aaSubs <- str_split(string = aaSubs, pattern = ",")
    
    
    
#     break
# }

# %%
dim(df)
# Out:
# [1] 11609119       24

# %%
# Apply the function to extract AA substitutions
DF$AA_Substitutions <- lapply(DF[, "AA Substitutions"], stringManipulation)
# Out:
# [1] "character"
# [1] "list"

# %%
DF
# Out:
#   Virus name                              Last vaccinated
# 1 hCoV-19/England/MILK-3109B1B/2022
# 2 hCoV-19/USA/WI-WSLH-222668/2021
# 3 hCoV-19/England/MILK-30FD498/2022
# 4 hCoV-19/France/ARA-HCL021201855701/2021
# 5 hCoV-19/Germany/NW-RKI-I-433432/2022
# 6 hCoV-19/USA/CA-FS25406602/2021
#   Passage details/history Type            Accession ID    Collection date
# 1 Original                betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 Original                betacoronavirus EPI_ISL_9678637 2021-12-21
# 3 Original                betacoronavirus EPI_ISL_8532336 2022-01-03
# 4 Original                betacoronavirus EPI_ISL_6842886 2021-11-13
# 5 Original                betacoronavirus EPI_ISL_8682478 2022-01-11
# 6 Original                betacoronavirus EPI_ISL_4869788 2021-08-25
#   Location
# 1 Europe / United Kingdom / England
# 2 North America / USA / Wisconsin / Sheboygan County
# 3 Europe / United Kingdom / England
# 4 Europe / France / Auvergne-Rhone-Alpes
# ...

# %%
# Create a new dataframe with separate rows for each AA substitution
DF.unnest <- DF %>%
  unnest(cols = AA_Substitutions)
DF.unnest
# Out:
#     Virus name                        Last vaccinated Passage details/history
# 1   hCoV-19/England/MILK-3109B1B/2022                 Original
# 2   hCoV-19/England/MILK-3109B1B/2022                 Original
# 3   hCoV-19/England/MILK-3109B1B/2022                 Original
# 4   hCoV-19/England/MILK-3109B1B/2022                 Original
# 5   hCoV-19/England/MILK-3109B1B/2022                 Original
# 6   hCoV-19/England/MILK-3109B1B/2022                 Original
# 7   hCoV-19/England/MILK-3109B1B/2022                 Original
# 8   hCoV-19/England/MILK-3109B1B/2022                 Original
# 9   hCoV-19/England/MILK-3109B1B/2022                 Original
# 10  hCoV-19/England/MILK-3109B1B/2022                 Original
# 11  hCoV-19/England/MILK-3109B1B/2022                 Original
# 12  hCoV-19/England/MILK-3109B1B/2022                 Original
# 13  hCoV-19/England/MILK-3109B1B/2022                 Original
# 14  hCoV-19/England/MILK-3109B1B/2022                 Original
# ...

# %%
df1
# Out:
#          collection_date         mutation_name
# 1        2019-12-30 00:00:00.000 T104A
# 2        2019-12-30 00:00:00.000 A21137G
# 3        2019-12-30 00:00:00.000 G21316A
# 4        2019-12-30 00:00:00.000 T21656A
# 5        2019-12-30 00:00:00.000 A24325G
# 6        2020-01-01 00:00:00.000 C10078T
# 7        2020-01-01 00:00:00.000 G11230T
# 8        2020-01-01 00:00:00.000 G1156T
# 9        2020-01-01 00:00:00.000 C11653T
# 10       2020-01-01 00:00:00.000 C11916T
# 11       2020-01-01 00:00:00.000 T13195C
# 12       2020-01-01 00:00:00.000 A13396G
# 13       2020-01-01 00:00:00.000 G1397A
# 14       2020-01-01 00:00:00.000 G14118T
# 15       2020-01-01 00:00:00.000 G14371T
# 16       2020-01-01 00:00:00.000 C15720T
# 17       2020-01-01 00:00:00.000 C16058A
# 18       2020-01-01 00:00:00.000 G16622A
# 19       2020-01-01 00:00:00.000 A16889G
# 20       2020-01-01 00:00:00.000 G17019T
# 21       2020-01-01 00:00:00.000 A17423G
# 22       2020-01-01 00:00:00.000 G17623A
# ...

# %%
df2
# Out:
#       AccessionIDs CollectionDate   <NA>  <NA>   <NA>  <NA>     <NA>
# 1     A23403G      1|23403|A|G      23403 A      G     11692133 1.8290071
# 2     C3037T       1|3037|C|T        3037 C      T     11670729 1.8256589
# 3     C14408T      1|14408|C|T      14408 C      T     11669447 1.8254584
# 4     C241T        1|241|C|T          241 C      T     11499166 1.7988212
# 5     C22995A      1|22995|C|A      22995 C      A      9139297 1.4296655
# 6     C10029T      1|10029|C|T      10029 C      T      9106039 1.4244630
# 7     G28881A      1|28881|G|A      28881 G      A      6920541 1.0825842
# 8     G28883C      1|28883|G|C      28883 G      C      6861817 1.0733980
# 9     G28882A      1|28882|G|A      28882 G      A      6848258 1.0712770
# 10    C23604A      1|23604|C|A      23604 C      A      6640605 1.0387937
# 11    A23063T      1|23063|A|T      23063 A      T      6363684 0.9954748
# 12    G21987A      1|21987|G|A      21987 G      A      6103063 0.9547057
# ...

# %%
print("Step 1: string manipulation started...")
# Apply the function to extract AA substitutions
df$AA_Substitutions <- lapply(df[, "AA Substitutions"], stringManipulation)
print("Step 2: unnesting started...")
# Create a new dataframe with separate rows for each AA substitution
df.unnest <- df %>%
  unnest(cols = AA_Substitutions)
print("Step 3: saving dataframe started...")
saveRDS(df.unnest, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.manipulated.unnested.rds")
print("Execution successful!")
# Out:
# [1] "Step 1: string manipulation started..."
# [1] "character"
# [1] "list"
# [1] "Step 2: unnesting started..."
# [1] "Step 3: saving dataframe started..."
# [1] "Execution successful!"

# %% [markdown]
# ## Load df.unnest

# %%
dim(df3)

# %%
df.unnest <- readRDS("/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.manipulated.unnested.rds")

dim(df.unnest)
head(df.unnest)

# %%
head(df.unnest)
# Out:
#   Virus name                        Last vaccinated Passage details/history
# 1 hCoV-19/England/MILK-3109B1B/2022                 Original
# 2 hCoV-19/England/MILK-3109B1B/2022                 Original
# 3 hCoV-19/England/MILK-3109B1B/2022                 Original
# 4 hCoV-19/England/MILK-3109B1B/2022                 Original
# 5 hCoV-19/England/MILK-3109B1B/2022                 Original
# 6 hCoV-19/England/MILK-3109B1B/2022                 Original
#   Type            Accession ID    Collection date
# 1 betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 betacoronavirus EPI_ISL_8534541 2022-01-03
# 3 betacoronavirus EPI_ISL_8534541 2022-01-03
# 4 betacoronavirus EPI_ISL_8534541 2022-01-03
# 5 betacoronavirus EPI_ISL_8534541 2022-01-03
# 6 betacoronavirus EPI_ISL_8534541 2022-01-03
#   Location                          Additional location information
# 1 Europe / United Kingdom / England
# 2 Europe / United Kingdom / England
# 3 Europe / United Kingdom / England
# ...

# %%
DF
# Out:
#   Virus name                              Last vaccinated
# 1 hCoV-19/England/MILK-3109B1B/2022
# 2 hCoV-19/USA/WI-WSLH-222668/2021
# 3 hCoV-19/England/MILK-30FD498/2022
# 4 hCoV-19/France/ARA-HCL021201855701/2021
# 5 hCoV-19/Germany/NW-RKI-I-433432/2022
# 6 hCoV-19/USA/CA-FS25406602/2021
#   Passage details/history Type            Accession ID    Collection date
# 1 Original                betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 Original                betacoronavirus EPI_ISL_9678637 2021-12-21
# 3 Original                betacoronavirus EPI_ISL_8532336 2022-01-03
# 4 Original                betacoronavirus EPI_ISL_6842886 2021-11-13
# 5 Original                betacoronavirus EPI_ISL_8682478 2022-01-11
# 6 Original                betacoronavirus EPI_ISL_4869788 2021-08-25
#   Location
# 1 Europe / United Kingdom / England
# 2 North America / USA / Wisconsin / Sheboygan County
# 3 Europe / United Kingdom / England
# 4 Europe / France / Auvergne-Rhone-Alpes
# ...

# %%
colnames(DF.unnest)
# Out:
#  [1] "Virus name"                      "Last vaccinated"
#  [3] "Passage details/history"         "Type"
#  [5] "Accession ID"                    "Collection date"
#  [7] "Location"                        "Additional location information"
#  [9] "Sequence length"                 "Host"
# [11] "Patient age"                     "Gender"
# [13] "Clade"                           "Pango lineage"
# [15] "Pango version"                   "Variant"
# [17] "AA Substitutions"                "Submission date"
# [19] "Is reference?"                   "Is complete?"
# [21] "Is high coverage?"               "Is low coverage?"
# [23] "N-Content"                       "GC-Content"
# [25] "AA_Substitutions"

# %%
rename_with(DF.unnest, ~ tolower(gsub("[ ]", "_", .x, fixed = TRUE)))
# Out:
#     virus name                        last vaccinated passage details/history
# 1   hCoV-19/England/MILK-3109B1B/2022                 Original
# 2   hCoV-19/England/MILK-3109B1B/2022                 Original
# 3   hCoV-19/England/MILK-3109B1B/2022                 Original
# 4   hCoV-19/England/MILK-3109B1B/2022                 Original
# 5   hCoV-19/England/MILK-3109B1B/2022                 Original
# 6   hCoV-19/England/MILK-3109B1B/2022                 Original
# 7   hCoV-19/England/MILK-3109B1B/2022                 Original
# 8   hCoV-19/England/MILK-3109B1B/2022                 Original
# 9   hCoV-19/England/MILK-3109B1B/2022                 Original
# 10  hCoV-19/England/MILK-3109B1B/2022                 Original
# 11  hCoV-19/England/MILK-3109B1B/2022                 Original
# 12  hCoV-19/England/MILK-3109B1B/2022                 Original
# 13  hCoV-19/England/MILK-3109B1B/2022                 Original
# 14  hCoV-19/England/MILK-3109B1B/2022                 Original
# ...

# %%
class(df.unnest)
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"

# %%
table(df.unnest[, "Is complete?"], useNA = "always")
# Out:
# Is complete?
#      TRUE      <NA>
# 509825780       134

# %%
DF.unnest.fil <- DF.unnest %>%
    select("Collection date", "AA_Substitutions") %>%
    rename("collection_date" = "Collection date", "aa_subs" = "AA_Substitutions")

DF.unnest.fil$collection_date <- as_date(DF.unnest.fil$collection_date)

DF.unnest.fil
# Out:
#     collection_date aa_subs
# 1   2022-01-03      NSP5_P132H
# 2   2022-01-03      Spike_H69del
# 3   2022-01-03      Spike_T95I
# 4   2022-01-03      Spike_A67V
# 5   2022-01-03      Spike_S373P
# 6   2022-01-03      Spike_Q493R
# 7   2022-01-03      Spike_N969K
# 8   2022-01-03      Spike_H655Y
# 9   2022-01-03      Spike_N856K
# 10  2022-01-03      N_R203K
# 11  2022-01-03      Spike_G142D
# 12  2022-01-03      NSP3_A1892T
# 13  2022-01-03      Spike_Q954H
# 14  2022-01-03      NS3_D155Y
# 15  2022-01-03      N_P13L
# 16  2022-01-03      NSP3_L1266I
# 17  2022-01-03      Spike_N501Y
# 18  2022-01-03      N_R32del
# 19  2022-01-03      M_Q19E
# 20  2022-01-03      NSP4_T492I
# 21  2022-01-03      NSP6_L105del
# 22  2022-01-03      Spike_N679K
# 23  2022-01-03      Spike_N764K
# 24  2022-01-03      Spike_L212I
# 25  2022-01-03      NSP6_G107del
# 26  2022-01-03      Spike_Y505H
# 27  2022-01-03      NSP6_I189V
# 28  2022-01-03      Spike_T547K
# 29  2022-01-03      M_D3G
# ...

# %%
head(df.unnest)
# Out:
#   Virus name                        Last vaccinated Passage details/history
# 1 hCoV-19/England/MILK-3109B1B/2022                 Original
# 2 hCoV-19/England/MILK-3109B1B/2022                 Original
# 3 hCoV-19/England/MILK-3109B1B/2022                 Original
# 4 hCoV-19/England/MILK-3109B1B/2022                 Original
# 5 hCoV-19/England/MILK-3109B1B/2022                 Original
# 6 hCoV-19/England/MILK-3109B1B/2022                 Original
#   Type            Accession ID    Collection date
# 1 betacoronavirus EPI_ISL_8534541 2022-01-03
# 2 betacoronavirus EPI_ISL_8534541 2022-01-03
# 3 betacoronavirus EPI_ISL_8534541 2022-01-03
# 4 betacoronavirus EPI_ISL_8534541 2022-01-03
# 5 betacoronavirus EPI_ISL_8534541 2022-01-03
# 6 betacoronavirus EPI_ISL_8534541 2022-01-03
#   Location                          Additional location information
# 1 Europe / United Kingdom / England
# 2 Europe / United Kingdom / England
# 3 Europe / United Kingdom / England
# ...

# %%
head(DF.unnest.fil)
# Out:
#   collection_date aa_subs
# 1 2022-01-03      NSP5_P132H
# 2 2022-01-03      Spike_H69del
# 3 2022-01-03      Spike_T95I
# 4 2022-01-03      Spike_A67V
# 5 2022-01-03      Spike_S373P
# 6 2022-01-03      Spike_Q493R

# %%
head(df1, 2)
# Out:
#   collection_date         mutation_name mutation_str pos   ref alt count
# 1 2019-12-30 00:00:00.000 T104A         1|104|T|A      104 T   A   1
# 2 2019-12-30 00:00:00.000 A21137G       1|21137|A|G  21137 A   G   1

# %%
head(df2, 2)
# Out:
#   AccessionIDs CollectionDate <NA>  <NA> <NA> <NA>     <NA>
# 1 A23403G      1|23403|A|G    23403 A    G    11692133 1.829007
# 2 C3037T       1|3037|C|T      3037 C    T    11670729 1.825659

# %%
DF.unnest.fil %>%
    mutate(region=str_split(string = aa_subs, pattern = "_"))
# Out:
#     collection_date aa_subs      region
# 1   2022-01-03      NSP5_P132H   NSP5 , P132H
# 2   2022-01-03      Spike_H69del Spike , H69del
# 3   2022-01-03      Spike_T95I   Spike, T95I
# 4   2022-01-03      Spike_A67V   Spike, A67V
# 5   2022-01-03      Spike_S373P  Spike, S373P
# 6   2022-01-03      Spike_Q493R  Spike, Q493R
# 7   2022-01-03      Spike_N969K  Spike, N969K
# 8   2022-01-03      Spike_H655Y  Spike, H655Y
# 9   2022-01-03      Spike_N856K  Spike, N856K
# 10  2022-01-03      N_R203K      N    , R203K
# 11  2022-01-03      Spike_G142D  Spike, G142D
# 12  2022-01-03      NSP3_A1892T  NSP3  , A1892T
# 13  2022-01-03      Spike_Q954H  Spike, Q954H
# 14  2022-01-03      NS3_D155Y    NS3  , D155Y
# 15  2022-01-03      N_P13L       N   , P13L
# 16  2022-01-03      NSP3_L1266I  NSP3  , L1266I
# 17  2022-01-03      Spike_N501Y  Spike, N501Y
# 18  2022-01-03      N_R32del     N     , R32del
# 19  2022-01-03      M_Q19E       M   , Q19E
# ...

# %%
# Assuming you have loaded the required libraries and generated the output as shown

DF.unnest.fil %>%
  mutate(region = str_split(string = aa_subs, pattern = "_")) %>%
  mutate(region = sapply(region, function(x) x[1]))
# Out:
#     collection_date aa_subs      region
# 1   2022-01-03      NSP5_P132H   NSP5
# 2   2022-01-03      Spike_H69del Spike
# 3   2022-01-03      Spike_T95I   Spike
# 4   2022-01-03      Spike_A67V   Spike
# 5   2022-01-03      Spike_S373P  Spike
# 6   2022-01-03      Spike_Q493R  Spike
# 7   2022-01-03      Spike_N969K  Spike
# 8   2022-01-03      Spike_H655Y  Spike
# 9   2022-01-03      Spike_N856K  Spike
# 10  2022-01-03      N_R203K      N
# 11  2022-01-03      Spike_G142D  Spike
# 12  2022-01-03      NSP3_A1892T  NSP3
# 13  2022-01-03      Spike_Q954H  Spike
# 14  2022-01-03      NS3_D155Y    NS3
# 15  2022-01-03      N_P13L       N
# 16  2022-01-03      NSP3_L1266I  NSP3
# 17  2022-01-03      Spike_N501Y  Spike
# 18  2022-01-03      N_R32del     N
# 19  2022-01-03      M_Q19E       M
# 20  2022-01-03      NSP4_T492I   NSP4
# 21  2022-01-03      NSP6_L105del NSP6
# 22  2022-01-03      Spike_N679K  Spike
# 23  2022-01-03      Spike_N764K  Spike
# ...

# %%
# Assuming you have loaded the required libraries and generated the output as shown

DF1B <- DF.unnest.fil %>%
    mutate(region = str_split(string = aa_subs, pattern = "_")) %>%
    mutate(mutation_name = sapply(region, function(x) x[2]), region = sapply(region, function(x) x[1]))

DF1B
# Out:
#     collection_date aa_subs      region mutation_name
# 1   2022-01-03      NSP5_P132H   NSP5   P132H
# 2   2022-01-03      Spike_H69del Spike  H69del
# 3   2022-01-03      Spike_T95I   Spike  T95I
# 4   2022-01-03      Spike_A67V   Spike  A67V
# 5   2022-01-03      Spike_S373P  Spike  S373P
# 6   2022-01-03      Spike_Q493R  Spike  Q493R
# 7   2022-01-03      Spike_N969K  Spike  N969K
# 8   2022-01-03      Spike_H655Y  Spike  H655Y
# 9   2022-01-03      Spike_N856K  Spike  N856K
# 10  2022-01-03      N_R203K      N      R203K
# 11  2022-01-03      Spike_G142D  Spike  G142D
# 12  2022-01-03      NSP3_A1892T  NSP3   A1892T
# 13  2022-01-03      Spike_Q954H  Spike  Q954H
# 14  2022-01-03      NS3_D155Y    NS3    D155Y
# 15  2022-01-03      N_P13L       N      P13L
# 16  2022-01-03      NSP3_L1266I  NSP3   L1266I
# 17  2022-01-03      Spike_N501Y  Spike  N501Y
# 18  2022-01-03      N_R32del     N      R32del
# 19  2022-01-03      M_Q19E       M      Q19E
# ...

# %%
DF2B <- DF.unnest.fil %>%
    group_by(aa_subs) %>%
    summarise(counts = n()) %>%
    ungroup() %>%
    arrange(desc(counts))

DF2B
# Out:
#     aa_subs       counts
# 1   NSP4_T492I    6
# 2   Spike_D614G   6
# 3   NSP12_P323L   5
# 4   Spike_T478K   5
# 5   Spike_G142D   4
# 6   Spike_T95I    4
# 7   E_T9I         3
# 8   M_A63T        3
# 9   M_D3G         3
# 10  M_I82T        3
# 11  M_Q19E        3
# 12  NS3_S26L      3
# 13  NS7a_T120I    3
# 14  NS7a_V82A     3
# 15  NS7b_T40I     3
# 16  NSP12_G671S   3
# 17  NSP13_P77L    3
# 18  NSP14_A394V   3
# 19  NSP14_I42V    3
# 20  NSP3_A1892T   3
# 21  NSP3_A488S    3
# 22  NSP3_K38R     3
# 23  NSP3_L1266I   3
# 24  NSP3_P1228L   3
# 25  NSP3_P1469S   3
# 26  NSP3_S1265del 3
# 27  NSP4_V167L    3
# 28  NSP5_P132H    3
# 29  NSP6_G107del  3
# 30  NSP6_I189V    3
# ... ...           ...
# 83  NS3_D155Y     1
# 84  NS3_G49D      1
# 85  NS3_L106F     1
# 86  NS3_P240L     1
# 87  NS3_T223I     1
# 88  NS7a_A79V     1
# 89  NS7a_R118G    1
# 90  NSP12_C730R   1
# 91  NSP12_M110V   1
# 92  NSP12_P323F   1
# 93  NSP12_R349G   1
# 94  NSP13_L176F   1
# 95  NSP14_V14L    1
# ...

# %%
print("Started subsetting...")
df.unnest.fil <- df.unnest %>%
    select("Collection date", "AA_Substitutions") %>%
    rename("collection_date" = "Collection date", "aa_subs" = "AA_Substitutions")

print("Started changing the format...")
df.unnest.fil$collection_date <- as_date(df.unnest.fil$collection_date)

dim(df.unnest.fil)
head(df.unnest.fil)
# Out:
# [1] "Started subsetting..."
# [1] "Started changing the format..."
# Warning message:
# " 4074437 failed to parse."
# [1] 509825914         2
#   collection_date aa_subs
# 1 2022-01-03      NSP5_P132H
# 2 2022-01-03      Spike_H69del
# 3 2022-01-03      Spike_T95I
# 4 2022-01-03      Spike_A67V
# 5 2022-01-03      Spike_S373P
# 6 2022-01-03      Spike_Q493R

# %%
# Assuming you have loaded the required libraries and generated the output as shown
print("Started creating DF1...")
DF1 <- df.unnest.fil %>%
    mutate(region = str_split(string = aa_subs, pattern = "_")) %>%
    mutate(mutation_name = sapply(region, function(x) x[2]), region = sapply(region, function(x) x[1]))

dim(DF1)
head(DF1)

print("Started saving DF1...")
saveRDS(DF1, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF1.rds")
print("Saved DF1 successfully!")
# Out:
# [1] "Started creating DF1..."
# [1] 509825914         4
#   collection_date aa_subs      region mutation_name
# 1 2022-01-03      NSP5_P132H   NSP5   P132H
# 2 2022-01-03      Spike_H69del Spike  H69del
# 3 2022-01-03      Spike_T95I   Spike  T95I
# 4 2022-01-03      Spike_A67V   Spike  A67V
# 5 2022-01-03      Spike_S373P  Spike  S373P
# 6 2022-01-03      Spike_Q493R  Spike  Q493R
# [1] "Started saving DF1..."
# [1] "Saved DF1 successfully!"

# %%
print("Started creating DF2...")
DF2 <- df.unnest.fil %>%
    group_by(aa_subs) %>%
    summarise(counts = n()) %>%
    ungroup() %>%
    arrange(desc(counts))

dim(DF2)
head(DF2)
print("Started saving DF2...")
saveRDS(DF2, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.rds")
print("Saved DF2 successfully!")
# Out:
# [1] "Started creating DF2..."
# [1] 133862      2
#   aa_subs     counts
# 1 Spike_D614G 11551573
# 2 NSP12_P323L 11513173
# 3 Spike_T478K  9024745
# 4 NSP4_T492I   8993496
# 5 Spike_G142D  7847034
# 6 N_R203K      6758704
# [1] "Started saving DF2..."
# [1] "Saved DF2 successfully!"

# %% [markdown]
# # Mutating dataframes

# %%
nseqs <- nrow(df)
nseqs
# Out:
# [1] 11609119

# %%
tmp2 <- head(DF1, n = 100000)
tmp2
# Out:
#        collection_date aa_subs       region mutation_name
# 1      2022-01-03      NSP5_P132H    NSP5   P132H
# 2      2022-01-03      Spike_H69del  Spike  H69del
# 3      2022-01-03      Spike_T95I    Spike  T95I
# 4      2022-01-03      Spike_A67V    Spike  A67V
# 5      2022-01-03      Spike_S373P   Spike  S373P
# 6      2022-01-03      Spike_Q493R   Spike  Q493R
# 7      2022-01-03      Spike_N969K   Spike  N969K
# 8      2022-01-03      Spike_H655Y   Spike  H655Y
# 9      2022-01-03      Spike_N856K   Spike  N856K
# 10     2022-01-03      N_R203K       N      R203K
# 11     2022-01-03      Spike_G142D   Spike  G142D
# 12     2022-01-03      NSP3_A1892T   NSP3   A1892T
# 13     2022-01-03      Spike_Q954H   Spike  Q954H
# 14     2022-01-03      NS3_D155Y     NS3    D155Y
# 15     2022-01-03      N_P13L        N      P13L
# 16     2022-01-03      NSP3_L1266I   NSP3   L1266I
# 17     2022-01-03      Spike_N501Y   Spike  N501Y
# 18     2022-01-03      N_R32del      N      R32del
# ...

# %%
tmp2.unique
# Out:
#      collection_date aa_subs      region mutation_name
# 1    2020-03-15      NSP2_K112T   NSP2   K112T
# 2    2020-03-15      NSP12_P323L  NSP12  P323L
# 3    2020-03-15      Spike_D614G  Spike  D614G
# 4    2020-03-15      NSP15_N11S   NSP15  N11S
# 5    2020-03-15      NSP4_T327I   NSP4   T327I
# 6    2020-03-15      NS3_G196V    NS3    G196V
# 7    2020-03-15      NSP4_F308Y   NSP4   F308Y
# 8    2020-03-15      N_S197L      N      S197L
# 9    2020-03-15      NS8_L84S     NS8    L84S
# 10   2020-03-15      NSP3_S400G   NSP3   S400G
# 11   2020-03-16      N_S194L      N      S194L
# 12   2020-03-18      NS3_G251V    NS3    G251V
# 13   2020-03-18      NSP2_I559V   NSP2   I559V
# 14   2020-03-18      NSP2_P585S   NSP2   P585S
# 15   2020-03-18      NSP6_L37F    NSP6   L37F
# 16   2020-03-23      Spike_G1219V Spike  G1219V
# 17   2020-03-27      NSP12_A16V   NSP12  A16V
# 18   2020-03-27      NS3_Q57H     NS3    Q57H
# 19   2020-03-27      NSP2_T85I    NSP2   T85I
# ...

# %%
tmp2.unique <- tmp2 %>%
  arrange(collection_date) %>%
  distinct(aa_subs, .keep_all = TRUE)

dim(tmp2.unique)
head(tmp2.unique)
# Out:
# [1] 3174    4
#   collection_date aa_subs     region mutation_name
# 1 2020-03-15      NSP2_K112T  NSP2   K112T
# 2 2020-03-15      NSP12_P323L NSP12  P323L
# 3 2020-03-15      Spike_D614G Spike  D614G
# 4 2020-03-15      NSP15_N11S  NSP15  N11S
# 5 2020-03-15      NSP4_T327I  NSP4   T327I
# 6 2020-03-15      NS3_G196V   NS3    G196V

# %%
print("Started computing DF1.unique ...")
DF1.unique <- DF1 %>%
  arrange(collection_date) %>%
  distinct(aa_subs, .keep_all = TRUE)

dim(DF1.unique)
head(DF1.unique)

print("Started saving DF1.unique ...")
saveRDS(DF1.unique, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF1.unique.rds")
print("Saved DF1.unique successfully!")
# Out:
# [1] "Started computing DF1.unique ..."
# [1] 133862      4
#   collection_date aa_subs     region mutation_name
# 1 2019-12-24      NSP4_F145I  NSP4   F145I
# 2 2019-12-24      NSP3_N1890S NSP3   N1890S
# 3 2019-12-26      NSP6_N264K  NSP6   N264K
# 4 2019-12-26      NSP3_L1417I NSP3   L1417I
# 5 2019-12-30      NSP16_K160R NSP16  K160R
# 6 2019-12-30      NSP3_G1433S NSP3   G1433S
# [1] "Started saving DF1.unique ..."
# [1] "Saved DF1.unique successfully!"

# %%
table(DF1.unique$region)
# Out:
#           E     M     N   NS3   NS6  NS7a  NS7b   NS8  NSP1 NSP10 NSP12 NSP13
#     1   864  3280  6563  4365   903  2787   671  2585  2350  1395 10606  6862
# NSP14 NSP15 NSP16  NSP2  NSP3  NSP4  NSP5  NSP6  NSP7  NSP8  NSP9 Spike
#  6357  4831  4043  8425 26960  6594  3759  3711   757  1967   958 22268

# %%
DF1.unique.copy <- DF1.unique
# Removing the mutation which has no info on aa_subs
DF1.unique <- DF1.unique[-which(DF1.unique$region == ""),]
DF1.unique
# Out:
#        collection_date aa_subs                        region
# 1      2019-12-24      NSP4_F145I                     NSP4
# 2      2019-12-24      NSP3_N1890S                    NSP3
# 3      2019-12-26      NSP6_N264K                     NSP6
# 4      2019-12-26      NSP3_L1417I                    NSP3
# 5      2019-12-30      NSP16_K160R                    NSP16
# 6      2019-12-30      NSP3_G1433S                    NSP3
# 7      2019-12-30      NSP3_I1426T                    NSP3
# 8      2019-12-30      Spike_F32I                     Spike
# 9      2019-12-30      NSP3_S743P                     NSP3
# 10     2019-12-30      NS8_L84S                       NS8
# 11     2019-12-30      NSP16_D220N                    NSP16
# 12     2019-12-30      NSP4_T327I                     NSP4
# 13     2019-12-30      NSP3_D1761A                    NSP3
# 14     2020-01-01      NS7a_P34S                      NS7a
# 15     2020-01-01      NSP7_S25L                      NSP7
# ...

# %%
DF1.unique <- DF1.unique %>%
    mutate(
    ref = sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\1", mutation_name),
    pos = as.integer(sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\2", mutation_name)),
    alt = sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\3", mutation_name)
  )
DF1.unique
# Out:
#        collection_date aa_subs                        region
# 1      2019-12-24      NSP4_F145I                     NSP4
# 2      2019-12-24      NSP3_N1890S                    NSP3
# 3      2019-12-26      NSP6_N264K                     NSP6
# 4      2019-12-26      NSP3_L1417I                    NSP3
# 5      2019-12-30      NSP16_K160R                    NSP16
# 6      2019-12-30      NSP3_G1433S                    NSP3
# 7      2019-12-30      NSP3_I1426T                    NSP3
# 8      2019-12-30      Spike_F32I                     Spike
# 9      2019-12-30      NSP3_S743P                     NSP3
# 10     2019-12-30      NS8_L84S                       NS8
# 11     2019-12-30      NSP16_D220N                    NSP16
# 12     2019-12-30      NSP4_T327I                     NSP4
# 13     2019-12-30      NSP3_D1761A                    NSP3
# 14     2020-01-01      NS7a_P34S                      NS7a
# 15     2020-01-01      NSP7_S25L                      NSP7
# ...

# %%
DF1.unique <- DF1.unique[!(is.na(DF1.unique$collection_date)), ]
DF1.unique
# Out:
#        collection_date aa_subs                             region
# 1      2019-12-24      NSP4_F145I                          NSP4
# 2      2019-12-24      NSP3_N1890S                         NSP3
# 3      2019-12-26      NSP6_N264K                          NSP6
# 4      2019-12-26      NSP3_L1417I                         NSP3
# 5      2019-12-30      NSP16_K160R                         NSP16
# 6      2019-12-30      NSP3_G1433S                         NSP3
# 7      2019-12-30      NSP3_I1426T                         NSP3
# 8      2019-12-30      Spike_F32I                          Spike
# 9      2019-12-30      NSP3_S743P                          NSP3
# 10     2019-12-30      NS8_L84S                            NS8
# 11     2019-12-30      NSP16_D220N                         NSP16
# 12     2019-12-30      NSP4_T327I                          NSP4
# 13     2019-12-30      NSP3_D1761A                         NSP3
# 14     2020-01-01      NS7a_P34S                           NS7a
# ...

# %%
print("Started saving DF1.unique.mutated ...")
saveRDS(DF1.unique, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF1.unique.mutated.rds")
print("Saved DF1.unique.mutated successfully!")
# Out:
# [1] "Started saving DF1.unique.mutated ..."
# [1] "Saved DF1.unique.mutated successfully!"

# %%
# Very low per_abundance of 1392 mutations with missing collection dates
filter(DF2, aa_subs %in% DF1.unique[is.na(DF1.unique$collection_date),]$aa_subs) %>%
    arrange(desc(per_abundance))
# Out:
#      aa_subs                         counts region mutation_name
# 1    NSP1_L21G                       57     NSP1   L21G
# 2    NS3_I118P                       25     NS3    I118P
# 3    NS3_L115H                       25     NS3    L115H
# 4    NS3_N119P                       25     NS3    N119P
# 5    NSP14_Y69K                      21     NSP14  Y69K
# 6    NSP5_T280R                      21     NSP5   T280R
# 7    NSP12_V30P                      20     NSP12  V30P
# 8    Spike_L699A                     20     Spike  L699A
# 9    NSP1_V20E                       19     NSP1   V20E
# 10   NSP5_I281N                      18     NSP5   I281N
# 11   NSP3_ins760P                    15     NSP3   ins760P
# 12   NS3_H150S                       13     NS3    H150S
# 13   NS3_R126F                       13     NS3    R126F
# 14   NSP14_P70G                      13     NSP14  P70G
# 15   Spike_S698D                     13     Spike  S698D
# ...

# %%
# remove 1392 mutations with missing collection_date
DF2 <- filter(DF2, aa_subs %in% DF1.unique$aa_subs)
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
table(DF1.unique$region)
# Out:
#     E     M     N   NS3   NS6  NS7a  NS7b   NS8  NSP1 NSP10 NSP12 NSP13 NSP14
#   864  3280  6563  4365   903  2787   671  2585  2350  1395 10606  6862  6357
# NSP15 NSP16  NSP2  NSP3  NSP4  NSP5  NSP6  NSP7  NSP8  NSP9 Spike
#  4831  4043  8425 26960  6594  3759  3711   757  1967   958 22268

# %%
table(DF2$region)
sum(table(DF2$region))
# Out:
#     E     M     N   NS3   NS6  NS7a  NS7b   NS8  NSP1 NSP10 NSP12 NSP13 NSP14
#   864  3280  6563  4365   903  2787   671  2585  2350  1395 10606  6862  6357
# NSP15 NSP16  NSP2  NSP3  NSP4  NSP5  NSP6  NSP7  NSP8  NSP9 Spike
#  4831  4043  8425 26960  6594  3759  3711   757  1967   958 22268
# [1] 133861

# %%
identical(table(DF1.unique$region), table(DF2$region))
# Out:
# [1] TRUE

# %%
head(DF1)
# Out:
#   collection_date aa_subs      region mutation_name
# 1 2022-01-03      NSP5_P132H   NSP5   P132H
# 2 2022-01-03      Spike_H69del Spike  H69del
# 3 2022-01-03      Spike_T95I   Spike  T95I
# 4 2022-01-03      Spike_A67V   Spike  A67V
# 5 2022-01-03      Spike_S373P  Spike  S373P
# 6 2022-01-03      Spike_Q493R  Spike  Q493R

# %%
DF2 <- DF2 %>%
    mutate(region = str_split(string = aa_subs, pattern = "_")) %>%
    mutate(mutation_name = sapply(region, function(x) x[2]), region = sapply(region, function(x) x[1])) %>%
    mutate(fraction = counts / nseqs) %>%
    mutate(per_abundance = fraction * 100)

DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
sort(table(DF2$region), decreasing = TRUE)
# Out:
#  NSP3 Spike NSP12  NSP2 NSP13  NSP4     N NSP14 NSP15   NS3 NSP16  NSP5  NSP6
# 26960 22268 10606  8425  6862  6594  6563  6357  4831  4365  4043  3759  3711
#     M  NS7a   NS8  NSP1  NSP8 NSP10  NSP9   NS6     E  NSP7  NS7b
#  3280  2787  2585  2350  1967  1395   958   903   864   757   671     1

# %%
unique(DF2$region)
# Out:
#  [1] "Spike" "NSP12" "NSP4"  "N"     "NSP6"  "NSP5"  "M"     "E"     "NSP14"
# [10] "NS3"   "NSP13" "NS7a"  "NSP3"  "NSP1"  "NSP15" "NS7b"  "NS8"   "NSP2"
# [19] "NSP16" "NSP8"  "NSP9"  "NS6"   "NSP7"  "NSP10" ""

# %%
DF2.copy <- DF2

# %%
# DF2 <- DF2.copy
# Removing the mutation which has no info on aa_subs
DF2 <- DF2[-which(DF2$region == ""),]
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
sort(table(DF2$region), decreasing = TRUE)
# Out:
#  NSP3 Spike NSP12  NSP2 NSP13  NSP4     N NSP14 NSP15   NS3 NSP16  NSP5  NSP6
# 26960 22268 10606  8425  6862  6594  6563  6357  4831  4365  4043  3759  3711
#     M  NS7a   NS8  NSP1  NSP8 NSP10  NSP9   NS6     E  NSP7  NS7b
#  3280  2787  2585  2350  1967  1395   958   903   864   757   671

# %%
unique(DF2$region)
# Out:
#  [1] "Spike" "NSP12" "NSP4"  "N"     "NSP6"  "NSP5"  "M"     "E"     "NSP14"
# [10] "NS3"   "NSP13" "NS7a"  "NSP3"  "NSP1"  "NSP15" "NS7b"  "NS8"   "NSP2"
# [19] "NSP16" "NSP8"  "NSP9"  "NS6"   "NSP7"  "NSP10"

# %%
head(DF1)
# Out:
#   collection_date aa_subs      region mutation_name
# 1 2022-01-03      NSP5_P132H   NSP5   P132H
# 2 2022-01-03      Spike_H69del Spike  H69del
# 3 2022-01-03      Spike_T95I   Spike  T95I
# 4 2022-01-03      Spike_A67V   Spike  A67V
# 5 2022-01-03      Spike_S373P  Spike  S373P
# 6 2022-01-03      Spike_Q493R  Spike  Q493R

# %%
DF2 <- DF2 %>%
    mutate(
    ref = sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\1", mutation_name),
    pos = as.integer(sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\2", mutation_name)),
    alt = sub("^(.*[A-Za-z])(\\d+)([A-Za-z].*)$", "\\3", mutation_name)
  )
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
DF2.subs <- DF2 %>% filter(ref != "ins") %>%
    filter(ref != "del") %>%
    filter(alt != "ins") %>%
    filter(alt != "del")
DF2.subs
# Out:
#        aa_subs        counts   region mutation_name fraction     per_abundance
# 1      Spike_D614G    11551573 Spike  D614G         0.9950430    99.50430
# 2      NSP12_P323L    11513173 NSP12  P323L         0.9917353    99.17353
# 3      Spike_T478K     9024745 Spike  T478K         0.7773841    77.73841
# 4      NSP4_T492I      8993496 NSP4   T492I         0.7746924    77.46924
# 5      Spike_G142D     7847034 Spike  G142D         0.6759371    67.59371
# 6      N_R203K         6758704 N      R203K         0.5821892    58.21892
# 7      N_G204R         6691624 N      G204R         0.5764110    57.64110
# 8      Spike_P681H     6555302 Spike  P681H         0.5646683    56.46683
# 9      Spike_N501Y     6279437 Spike  N501Y         0.5409056    54.09056
# 10     Spike_H655Y     5601471 Spike  H655Y         0.4825061    48.25061
# 11     Spike_L452R     5505085 Spike  L452R         0.4742035    47.42035
# 12     Spike_N969K     5482415 Spike  N969K         0.4722507    47.22507
# ...

# %%
DF2.del <- filter(DF2, ref == "del" | alt == "del")
DF2.del
# Out:
#      aa_subs        counts  region mutation_name fraction     per_abundance ref
# 1    NSP6_G107del   6507129 NSP6   G107del       0.560518761  56.0518761    G
# 2    NSP6_S106del   6504001 NSP6   S106del       0.560249318  56.0249318    S
# 3    N_R32del       5210206 N      R32del        0.448802876  44.8802876    R
# 4    N_E31del       5205718 N      E31del        0.448416284  44.8416284    E
# 5    N_S33del       5066152 N      S33del        0.436394183  43.6394183    S
# 6    NSP6_F108del   4668427 NSP6   F108del       0.402134477  40.2134477    F
# 7    Spike_V70del   4440872 Spike  V70del        0.382533076  38.2533076    V
# 8    Spike_H69del   4437115 Spike  H69del        0.382209451  38.2209451    H
# 9    Spike_F157del  3620691 Spike  F157del       0.311883357  31.1883357    F
# 10   Spike_R158del  3617230 Spike  R158del       0.311585229  31.1585229    R
# 11   Spike_P26del   3402228 Spike  P26del        0.293065133  29.3065133    P
# ...

# %%
DF2.ins <- filter(DF2, ref == "ins" | alt == "ins")
DF2.ins
# Out:
#       aa_subs                                      counts  region
# 1     Spike_ins214EPE                              1522543 Spike
# 2     Spike_ins214XXX                                62968 Spike
# 3     NS3_ins104P                                    26716 NS3
# 4     NSP6_ins79M                                    11175 NSP6
# 5     Spike_ins143T                                  10172 Spike
# 6     NS7a_ins55YVPDQLH                               8156 NS7a
# 7     Spike_ins214GAR                                 4175 Spike
# 8     NSP5_ins159VT                                   3958 NSP5
# 9     NSP16_ins149S                                   3773 NSP16
# 10    Spike_ins213GRG                                 3664 Spike
# 11    Spike_ins212RE                                  3370 Spike
# 12    Spike_ins216XS                                  3299 Spike
# 13    NS3_ins104PP                                    2942 NS3
# 14    NS7a_ins60stopRRK                               2329 NS7a
# ...

# %%
nrow(DF2) == nrow(DF2.subs) + nrow(DF2.del) + nrow(DF2.ins)
# Out:
# [1] TRUE

# %%
DF2.Spike <- filter(DF2, region == "Spike")
DF2.N <- filter(DF2, region == "N")
DF2.M <- filter(DF2, region == "M")
DF2.E <- filter(DF2, region == "E")

DF2.NSP4 <- filter(DF2, region == "NSP4")
DF2.NSP13 <- filter(DF2, region == "NSP13")
DF2.NSP2 <- filter(DF2, region == "NSP2")
DF2.NSP12 <- filter(DF2, region == "NSP12")
DF2.NSP3 <- filter(DF2, region == "NSP3")


head(DF2.Spike, 2)
head(DF2.N, 2)
head(DF2.M, 2)
head(DF2.E, 2)
head(DF2.NSP4, 2)
head(DF2.NSP13, 2)
head(DF2.NSP2, 2)
head(DF2.NSP12, 2)
head(DF2.NSP3, 2)
# Out:
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 Spike_T478K  9024745 Spike  T478K         0.7773841 77.73841      T   478 K
#   aa_subs counts  region mutation_name fraction  per_abundance ref pos alt
# 1 N_R203K 6758704 N      R203K         0.5821892 58.21892      R   203 K
# 2 N_G204R 6691624 N      G204R         0.5764110 57.64110      G   204 R
#   aa_subs counts  region mutation_name fraction  per_abundance ref pos alt
# 1 M_A63T  5437134 M      A63T          0.4683503 46.83503      A   63  T
# 2 M_Q19E  5233720 M      Q19E          0.4508284 45.08284      Q   19  E
#   aa_subs counts  region mutation_name fraction   per_abundance ref pos alt
# 1 E_T9I   5433742 E      T9I           0.46805808 46.805808     T    9  I
# 2 E_T11A   374240 E      T11A          0.03223673  3.223673     T   11  A
# ...

# %%
nseqs
# Out:
# [1] 11609119

# %%
sort(table(DF2.subs$region), decreasing = T)
# Out:
#  NSP3 Spike NSP12  NSP2 NSP13  NSP4 NSP14     N NSP15 NSP16   NS3  NSP5  NSP6
# 22560 16939  9050  7044  5792  5463  5287  5235  4016  3395  3331  3233  3057
#     M  NSP1   NS8  NS7a  NSP8 NSP10  NSP9     E   NS6  NSP7  NS7b
#  2557  1905  1861  1839  1677  1176   824   720   706   649   516

# %%
DF2.geq1 <- filter(DF2, per_abundance >= 1)
DF2.geqpt1 <- filter(DF2, per_abundance >= 0.1)
DF2.geqpt01 <- filter(DF2, per_abundance >= 0.01)
DF2.top100 <- DF2 %>%
  arrange(desc(per_abundance)) %>%
  slice(1:100)

identical(DF2.top100, head(DF2, 100))

head(DF2.geq1, 2)
dim(DF2.geq1)

head(DF2.geqpt1, 2)
dim(DF2.geqpt1)

head(DF2.geqpt01, 2)
dim(DF2.geqpt01)

head(DF2.top100, 2)
dim(DF2.top100)
# Out:
# [1] TRUE
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 219   9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 903   9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 5452    9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# ...

# %%
DF2.subs.geq1 <- filter(DF2.subs, per_abundance >= 1)
DF2.subs.geqpt1 <- filter(DF2.subs, per_abundance >= 0.1)
DF2.subs.geqpt01 <- filter(DF2.subs, per_abundance >= 0.01)
DF2.subs.top100 <- DF2.subs %>%
  arrange(desc(per_abundance)) %>%
  slice(1:100)

identical(DF2.subs.top100, head(DF2.subs, 100))

head(DF2.subs.geq1, 2)
dim(DF2.subs.geq1)

head(DF2.subs.geqpt1, 2)
dim(DF2.subs.geqpt1)

head(DF2.subs.geqpt01, 2)
dim(DF2.subs.geqpt01)

head(DF2.subs.top100, 2)
dim(DF2.subs.top100)
# Out:
# [1] TRUE
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 190   9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 851   9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 NSP12_P323L 11513173 NSP12  P323L         0.9917353 99.17353      P   323 L
# [1] 5211    9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# ...

# %%
sort(table(DF2.subs.geq1$region), decreasing = T)
# Out:
# Spike     N  NSP3 NSP13   NS3  NSP6 NSP12  NSP4     M   NS8  NS7a NSP14  NSP2
#    79    20    17    10     8     8     7     7     6     6     3     3     3
#  NSP5     E  NS7b  NSP1 NSP16 NSP15  NSP8
#     3     2     2     2     2     1     1

# %%
DF2.subs.Spike <- filter(DF2.subs, region == "Spike")
DF2.subs.N <- filter(DF2.subs, region == "N")
DF2.subs.M <- filter(DF2.subs, region == "M")
DF2.subs.E <- filter(DF2.subs, region == "E")

DF2.subs.NSP4 <- filter(DF2.subs, region == "NSP4")
DF2.subs.NSP13 <- filter(DF2.subs, region == "NSP13")
DF2.subs.NSP2 <- filter(DF2.subs, region == "NSP2")
DF2.subs.NSP12 <- filter(DF2.subs, region == "NSP12")
DF2.subs.NSP3 <- filter(DF2.subs, region == "NSP3")


dim(DF2.subs.Spike)
head(DF2.subs.Spike, 2)

dim(DF2.subs.N)
head(DF2.subs.N, 2)

dim(DF2.subs.M)
head(DF2.subs.M, 2)

dim(DF2.subs.E)
head(DF2.subs.E, 2)

dim(DF2.subs.NSP4)
head(DF2.subs.NSP4, 2)

dim(DF2.subs.NSP13)
head(DF2.subs.NSP13, 2)

dim(DF2.subs.NSP2)
head(DF2.subs.NSP2, 2)

dim(DF2.subs.NSP12)
head(DF2.subs.NSP12, 2)

dim(DF2.subs.NSP3)
head(DF2.subs.NSP3, 2)
# Out:
# [1] 16939     9
#   aa_subs     counts   region mutation_name fraction  per_abundance ref pos alt
# 1 Spike_D614G 11551573 Spike  D614G         0.9950430 99.50430      D   614 G
# 2 Spike_T478K  9024745 Spike  T478K         0.7773841 77.73841      T   478 K
# [1] 5235    9
#   aa_subs counts  region mutation_name fraction  per_abundance ref pos alt
# 1 N_R203K 6758704 N      R203K         0.5821892 58.21892      R   203 K
# 2 N_G204R 6691624 N      G204R         0.5764110 57.64110      G   204 R
# [1] 2557    9
#   aa_subs counts  region mutation_name fraction  per_abundance ref pos alt
# 1 M_A63T  5437134 M      A63T          0.4683503 46.83503      A   63  T
# 2 M_Q19E  5233720 M      Q19E          0.4508284 45.08284      Q   19  E
# [1] 720   9
#   aa_subs counts  region mutation_name fraction   per_abundance ref pos alt
# 1 E_T9I   5433742 E      T9I           0.46805808 46.805808     T    9  I
# 2 E_T11A   374240 E      T11A          0.03223673  3.223673     T   11  A
# ...

# %%
DF2.subs.Spike
# Out:
#       aa_subs        counts   region mutation_name fraction     per_abundance
# 1     Spike_D614G    11551573 Spike  D614G         0.9950430    99.50430
# 2     Spike_T478K     9024745 Spike  T478K         0.7773841    77.73841
# 3     Spike_G142D     7847034 Spike  G142D         0.6759371    67.59371
# 4     Spike_P681H     6555302 Spike  P681H         0.5646683    56.46683
# 5     Spike_N501Y     6279437 Spike  N501Y         0.5409056    54.09056
# 6     Spike_H655Y     5601471 Spike  H655Y         0.4825061    48.25061
# 7     Spike_L452R     5505085 Spike  L452R         0.4742035    47.42035
# 8     Spike_N969K     5482415 Spike  N969K         0.4722507    47.22507
# 9     Spike_N679K     5479501 Spike  N679K         0.4719997    47.19997
# 10    Spike_Q954H     5477722 Spike  Q954H         0.4718465    47.18465
# 11    Spike_D796Y     5455993 Spike  D796Y         0.4699748    46.99748
# 12    Spike_S477N     5285659 Spike  S477N         0.4553023    45.53023
# ...

# %%
filter(DF2.subs.Spike, per_abundance >= 0.1)
# Out:
#     aa_subs      counts   region mutation_name fraction    per_abundance ref
# 1   Spike_D614G  11551573 Spike  D614G         0.9950430   99.50430      D
# 2   Spike_T478K   9024745 Spike  T478K         0.7773841   77.73841      T
# 3   Spike_G142D   7847034 Spike  G142D         0.6759371   67.59371      G
# 4   Spike_P681H   6555302 Spike  P681H         0.5646683   56.46683      P
# 5   Spike_N501Y   6279437 Spike  N501Y         0.5409056   54.09056      N
# 6   Spike_H655Y   5601471 Spike  H655Y         0.4825061   48.25061      H
# 7   Spike_L452R   5505085 Spike  L452R         0.4742035   47.42035      L
# 8   Spike_N969K   5482415 Spike  N969K         0.4722507   47.22507      N
# 9   Spike_N679K   5479501 Spike  N679K         0.4719997   47.19997      N
# 10  Spike_Q954H   5477722 Spike  Q954H         0.4718465   47.18465      Q
# 11  Spike_D796Y   5455993 Spike  D796Y         0.4699748   46.99748      D
# ...

# %% [markdown]
# # Plotting

# %%
tmp <- filter(DF2.subs.Spike, per_abundance >= 0.1)
tmp
# Out:
#     aa_subs      counts   region mutation_name fraction    per_abundance ref
# 1   Spike_D614G  11551573 Spike  D614G         0.9950430   99.50430      D
# 2   Spike_T478K   9024745 Spike  T478K         0.7773841   77.73841      T
# 3   Spike_G142D   7847034 Spike  G142D         0.6759371   67.59371      G
# 4   Spike_P681H   6555302 Spike  P681H         0.5646683   56.46683      P
# 5   Spike_N501Y   6279437 Spike  N501Y         0.5409056   54.09056      N
# 6   Spike_H655Y   5601471 Spike  H655Y         0.4825061   48.25061      H
# 7   Spike_L452R   5505085 Spike  L452R         0.4742035   47.42035      L
# 8   Spike_N969K   5482415 Spike  N969K         0.4722507   47.22507      N
# 9   Spike_N679K   5479501 Spike  N679K         0.4719997   47.19997      N
# 10  Spike_Q954H   5477722 Spike  Q954H         0.4718465   47.18465      Q
# 11  Spike_D796Y   5455993 Spike  D796Y         0.4699748   46.99748      D
# ...

# %%
# Create a sequence of positions
max_pos <- max(tmp$pos)
position_sequence <- seq(1, max_pos + 50, by = 1)

# %%
# Create a dataframe with filled positions and 0 per_abundance values
filled_df <- data.frame(pos = position_sequence) %>%
  left_join(tmp, by = "pos") %>%
  mutate(per_abundance = ifelse(is.na(per_abundance), 0, per_abundance))
# Out:
# Warning message in left_join(., tmp, by = "pos"):
# "Each row in `x` is expected to match at most 1 row in `y`.
# i Row 19 of `x` matches multiple rows.
# i If multiple matches are expected, set `multiple = "all"` to silence this warning."

# %%
filter(DF2.subs.Spike, per_abundance >= 0.1) %>% arrange(desc(pos))
# Out:
#     aa_subs      counts  region mutation_name fraction    per_abundance ref
# 1   Spike_V1264L  113375 Spike  V1264L        0.009766030  0.9766030    V
# 2   Spike_P1263L   15066 Spike  P1263L        0.001297773  0.1297773    P
# 3   Spike_D1259Y   18580 Spike  D1259Y        0.001600466  0.1600466    D
# 4   Spike_C1243F   12509 Spike  C1243F        0.001077515  0.1077515    C
# 5   Spike_M1237I   14696 Spike  M1237I        0.001265901  0.1265901    M
# 6   Spike_M1229I   12078 Spike  M1229I        0.001040389  0.1040389    M
# 7   Spike_V1228L   15905 Spike  V1228L        0.001370044  0.1370044    V
# 8   Spike_G1219V   13720 Spike  G1219V        0.001181830  0.1181830    G
# 9   Spike_G1219C   11858 Spike  G1219C        0.001021438  0.1021438    G
# 10  Spike_K1191N   43594 Spike  K1191N        0.003755151  0.3755151    K
# 11  Spike_V1176F  130776 Spike  V1176F        0.011264938  1.1264938    V
# 12  Spike_G1167V   15745 Spike  G1167V        0.001356261  0.1356261    G
# ...

# %%
# # insertions in Overall per_abundance >= 0.01%
# ins.DF2.geqpt01 <- filter(DF2.geqpt01, ref == "ins" | alt == "ins")
ins.DF2.geqpt01
# Out:
#    aa_subs                   counts  region mutation_name       fraction
# 1  Spike_ins214EPE           1522543 Spike  ins214EPE           0.1311506067
# 2  Spike_ins214XXX             62968 Spike  ins214XXX           0.0054240119
# 3  NS3_ins104P                 26716 NS3    ins104P             0.0023012944
# 4  NSP6_ins79M                 11175 NSP6   ins79M              0.0009626053
# 5  Spike_ins143T               10172 Spike  ins143T             0.0008762077
# 6  NS7a_ins55YVPDQLH            8156 NS7a   ins55YVPDQLH        0.0007025512
# 7  Spike_ins214GAR              4175 Spike  ins214GAR           0.0003596311
# 8  NSP5_ins159VT                3958 NSP5   ins159VT            0.0003409389
# 9  NSP16_ins149S                3773 NSP16  ins149S             0.0003250031
# 10 Spike_ins213GRG              3664 Spike  ins213GRG           0.0003156140
# 11 Spike_ins212RE               3370 Spike  ins212RE            0.0002902890
# ...

# %%
# # deletions in Overall per_abundance >= 0.01%
# del.DF2.geqpt01 <- filter(DF2.geqpt01, ref == "del" | alt == "del")
del.DF2.geqpt01
# Out:
#     aa_subs       counts  region mutation_name fraction     per_abundance ref
# 1   NSP6_G107del  6507129 NSP6   G107del       0.560518761  56.0518761    G
# 2   NSP6_S106del  6504001 NSP6   S106del       0.560249318  56.0249318    S
# 3   N_R32del      5210206 N      R32del        0.448802876  44.8802876    R
# 4   N_E31del      5205718 N      E31del        0.448416284  44.8416284    E
# 5   N_S33del      5066152 N      S33del        0.436394183  43.6394183    S
# 6   NSP6_F108del  4668427 NSP6   F108del       0.402134477  40.2134477    F
# 7   Spike_V70del  4440872 Spike  V70del        0.382533076  38.2533076    V
# 8   Spike_H69del  4437115 Spike  H69del        0.382209451  38.2209451    H
# 9   Spike_F157del 3620691 Spike  F157del       0.311883357  31.1883357    F
# 10  Spike_R158del 3617230 Spike  R158del       0.311585229  31.1585229    R
# 11  Spike_P26del  3402228 Spike  P26del        0.293065133  29.3065133    P
# ...

# %% [markdown]
# # Saving dataframes

# %%
print("Started saving DF2...")
saveRDS(DF2, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.mutated.rds")
print("Saved DF2 successfully!")
# Out:
# [1] "Started saving DF2..."
# [1] "Saved DF2 successfully!"

# %%
print("Started saving DF2 subs...")
saveRDS(DF2.subs, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.rds")
print("Saved DF2 subs successfully!")
# Out:
# [1] "Started saving DF2 subs..."
# [1] "Saved DF2 subs successfully!"

# %%
print("Started saving DF2 subs dataframes...")
write.csv(DF2.subs.geq1, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.geq1.csv")
write.csv(DF2.subs.geqpt1, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.geqpt1.csv")
write.csv(DF2.subs.geqpt01, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.geqpt01.csv")
write.csv(DF2.subs.top100, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.top100.csv")
print("Saved DF2 subs dataframes successfully!")
# Out:
# [1] "Started saving DF2 subs dataframes..."
# [1] "Saved DF2 subs dataframes successfully!"

# %%
print("Started saving DF2 subs dataframes...")
write.csv(DF2.geq1, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.geq1.csv")
write.csv(DF2.geqpt1, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.geqpt1.csv")
write.csv(DF2.geqpt01, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.geqpt01.csv")
write.csv(DF2.top100, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.top100.csv")
print("Saved DF2 subs dataframes successfully!")
# Out:
# [1] "Started saving DF2 subs dataframes..."
# [1] "Saved DF2 subs dataframes successfully!"

# %%
print("Started saving DF2 indel dataframes...")
write.csv(ins.DF2.geqpt01, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/ins.DF2.geqpt01.csv")
write.csv(del.DF2.geqpt01, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/del.DF2.geqpt01.csv")
print("Saved DF2 indel dataframes successfully!")
# Out:
# [1] "Started saving DF2 indel dataframes..."
# [1] "Saved DF2 indel dataframes successfully!"

# %%
# df <- readRDS(df.unnest, "/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/metadata.manipulated.unnested.rds")
# df

# %%
DF1.unique <- readRDS("/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF1.unique.mutated.rds")
DF1.unique
# Out:
#        collection_date aa_subs                             region
# 1      2019-12-24      NSP4_F145I                          NSP4
# 2      2019-12-24      NSP3_N1890S                         NSP3
# 3      2019-12-26      NSP6_N264K                          NSP6
# 4      2019-12-26      NSP3_L1417I                         NSP3
# 5      2019-12-30      NSP16_K160R                         NSP16
# 6      2019-12-30      NSP3_G1433S                         NSP3
# 7      2019-12-30      NSP3_I1426T                         NSP3
# 8      2019-12-30      Spike_F32I                          Spike
# 9      2019-12-30      NSP3_S743P                          NSP3
# 10     2019-12-30      NS8_L84S                            NS8
# 11     2019-12-30      NSP16_D220N                         NSP16
# 12     2019-12-30      NSP4_T327I                          NSP4
# 13     2019-12-30      NSP3_D1761A                         NSP3
# 14     2020-01-01      NS7a_P34S                           NS7a
# ...

# %%
DF2.subs.geq1 <- read.csv("/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.subs.geq1.csv")
DF2.subs.geq1
# Out:
#     X   aa_subs      counts   region mutation_name fraction   per_abundance ref
# 1    1  Spike_D614G  11551573 Spike  D614G         0.9950430  99.50430      D
# 2    2  NSP12_P323L  11513173 NSP12  P323L         0.9917353  99.17353      P
# 3    3  Spike_T478K   9024745 Spike  T478K         0.7773841  77.73841      T
# 4    4  NSP4_T492I    8993496 NSP4   T492I         0.7746924  77.46924      T
# 5    5  Spike_G142D   7847034 Spike  G142D         0.6759371  67.59371      G
# 6    6  N_R203K       6758704 N      R203K         0.5821892  58.21892      R
# 7    7  N_G204R       6691624 N      G204R         0.5764110  57.64110      G
# 8    8  Spike_P681H   6555302 Spike  P681H         0.5646683  56.46683      P
# 9    9  Spike_N501Y   6279437 Spike  N501Y         0.5409056  54.09056      N
# 10  10  Spike_H655Y   5601471 Spike  H655Y         0.4825061  48.25061      H
# 11  11  Spike_L452R   5505085 Spike  L452R         0.4742035  47.42035      L
# ...

# %%
DF1.unique
# Out:
#        collection_date aa_subs                             region
# 1      2019-12-24      NSP4_F145I                          NSP4
# 2      2019-12-24      NSP3_N1890S                         NSP3
# 3      2019-12-26      NSP6_N264K                          NSP6
# 4      2019-12-26      NSP3_L1417I                         NSP3
# 5      2019-12-30      NSP16_K160R                         NSP16
# 6      2019-12-30      NSP3_G1433S                         NSP3
# 7      2019-12-30      NSP3_I1426T                         NSP3
# 8      2019-12-30      Spike_F32I                          Spike
# 9      2019-12-30      NSP3_S743P                          NSP3
# 10     2019-12-30      NS8_L84S                            NS8
# 11     2019-12-30      NSP16_D220N                         NSP16
# 12     2019-12-30      NSP4_T327I                          NSP4
# 13     2019-12-30      NSP3_D1761A                         NSP3
# 14     2020-01-01      NS7a_P34S                           NS7a
# ...

# %%
DF2 <- readRDS("/ahg/regevdata/projects/ICA_Lung/Akhil/projects/prev/mutation_tracking/DF2.mutated.rds")
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
rownames(DF2) <- DF2$aa_subs
rownames(DF1.unique) <- DF1.unique$aa_subs
# Out:
# Warning message:
# "Setting row names on a tibble is deprecated."
# Warning message:
# "Setting row names on a tibble is deprecated."

# %%
DF1.unique.collectionDate <- DF1.unique["collection_date"]
rownames(DF1.unique.collectionDate) <- rownames(DF1.unique)
DF1.unique.collectionDate
# Out:
# Warning message:
# "Setting row names on a tibble is deprecated."
#        collection_date
# 1      2019-12-24
# 2      2019-12-24
# 3      2019-12-26
# 4      2019-12-26
# 5      2019-12-30
# 6      2019-12-30
# 7      2019-12-30
# 8      2019-12-30
# 9      2019-12-30
# 10     2019-12-30
# 11     2019-12-30
# 12     2019-12-30
# 13     2019-12-30
# 14     2020-01-01
# 15     2020-01-01
# 16     2020-01-01
# 17     2020-01-01
# 18     2020-01-01
# 19     2020-01-01
# 20     2020-01-01
# 21     2020-01-01
# 22     2020-01-01
# 23     2020-01-01
# 24     2020-01-01
# 25     2020-01-01
# 26     2020-01-01
# 27     2020-01-01
# 28     2020-01-01
# 29     2020-01-01
# 30     2020-01-01
# ...    ...
# 132440 2023-04-24
# 132441 2023-04-24
# 132442 2023-04-24
# 132443 2023-04-24
# 132444 2023-04-25
# 132445 2023-04-25
# 132446 2023-04-25
# 132447 2023-04-25
# 132448 2023-04-26
# 132449 2023-04-26
# 132450 2023-04-26
# 132451 2023-04-26
# 132452 2023-04-26
# 132453 2023-04-26
# ...

# %%
DF2
# Out:
#        aa_subs                                      counts   region
# 1      Spike_D614G                                  11551573 Spike
# 2      NSP12_P323L                                  11513173 NSP12
# 3      Spike_T478K                                   9024745 Spike
# 4      NSP4_T492I                                    8993496 NSP4
# 5      Spike_G142D                                   7847034 Spike
# 6      N_R203K                                       6758704 N
# 7      N_G204R                                       6691624 N
# 8      Spike_P681H                                   6555302 Spike
# 9      NSP6_G107del                                  6507129 NSP6
# 10     NSP6_S106del                                  6504001 NSP6
# 11     Spike_N501Y                                   6279437 Spike
# 12     Spike_H655Y                                   5601471 Spike
# 13     Spike_L452R                                   5505085 Spike
# ...

# %%
DF.p <- dplyr::bind_cols(DF1.unique.collectionDate, DF2)
DF.p
# Out:
#        collection_date aa_subs                                      counts
# 1      2019-12-24      Spike_D614G                                  11551573
# 2      2019-12-24      NSP12_P323L                                  11513173
# 3      2019-12-26      Spike_T478K                                   9024745
# 4      2019-12-26      NSP4_T492I                                    8993496
# 5      2019-12-30      Spike_G142D                                   7847034
# 6      2019-12-30      N_R203K                                       6758704
# 7      2019-12-30      N_G204R                                       6691624
# 8      2019-12-30      Spike_P681H                                   6555302
# 9      2019-12-30      NSP6_G107del                                  6507129
# 10     2019-12-30      NSP6_S106del                                  6504001
# 11     2019-12-30      Spike_N501Y                                   6279437
# ...

# %%
DF.p.subs <- DF.p %>% filter(ref != "ins") %>%
    filter(ref != "del") %>%
    filter(alt != "ins") %>%
    filter(alt != "del")
DF.p.subs
# Out:
#        collection_date aa_subs        counts   region mutation_name
# 1      2019-12-24      Spike_D614G    11551573 Spike  D614G
# 2      2019-12-24      NSP12_P323L    11513173 NSP12  P323L
# 3      2019-12-26      Spike_T478K     9024745 Spike  T478K
# 4      2019-12-26      NSP4_T492I      8993496 NSP4   T492I
# 5      2019-12-30      Spike_G142D     7847034 Spike  G142D
# 6      2019-12-30      N_R203K         6758704 N      R203K
# 7      2019-12-30      N_G204R         6691624 N      G204R
# 8      2019-12-30      Spike_P681H     6555302 Spike  P681H
# 9      2019-12-30      Spike_N501Y     6279437 Spike  N501Y
# 10     2019-12-30      Spike_H655Y     5601471 Spike  H655Y
# 11     2019-12-30      Spike_L452R     5505085 Spike  L452R
# 12     2020-01-01      Spike_N969K     5482415 Spike  N969K
# 13     2020-01-01      N_P13L          5482376 N      P13L
# 14     2020-01-01      Spike_N679K     5479501 Spike  N679K
# 15     2020-01-01      Spike_Q954H     5477722 Spike  Q954H
# ...

# %%
DF.p.subs.geqpt01 <- filter(DF.p.subs, per_abundance > 0.01)
DF.p.subs.geqpt01
# Out:
#      collection_date aa_subs     counts   region mutation_name fraction
# 1    2019-12-24      Spike_D614G 11551573 Spike  D614G         0.9950430
# 2    2019-12-24      NSP12_P323L 11513173 NSP12  P323L         0.9917353
# 3    2019-12-26      Spike_T478K  9024745 Spike  T478K         0.7773841
# 4    2019-12-26      NSP4_T492I   8993496 NSP4   T492I         0.7746924
# 5    2019-12-30      Spike_G142D  7847034 Spike  G142D         0.6759371
# 6    2019-12-30      N_R203K      6758704 N      R203K         0.5821892
# 7    2019-12-30      N_G204R      6691624 N      G204R         0.5764110
# 8    2019-12-30      Spike_P681H  6555302 Spike  P681H         0.5646683
# 9    2019-12-30      Spike_N501Y  6279437 Spike  N501Y         0.5409056
# 10   2019-12-30      Spike_H655Y  5601471 Spike  H655Y         0.4825061
# 11   2019-12-30      Spike_L452R  5505085 Spike  L452R         0.4742035
# 12   2020-01-01      Spike_N969K  5482415 Spike  N969K         0.4722507
# ...

# %%
DF.p.subs.geqpt1 <- filter(DF.p.subs, per_abundance > 0.1)
DF.p.subs.geqpt1
# Out:
#     collection_date aa_subs      counts   region mutation_name fraction
# 1   2019-12-24      Spike_D614G  11551573 Spike  D614G         0.9950430
# 2   2019-12-24      NSP12_P323L  11513173 NSP12  P323L         0.9917353
# 3   2019-12-26      Spike_T478K   9024745 Spike  T478K         0.7773841
# 4   2019-12-26      NSP4_T492I    8993496 NSP4   T492I         0.7746924
# 5   2019-12-30      Spike_G142D   7847034 Spike  G142D         0.6759371
# 6   2019-12-30      N_R203K       6758704 N      R203K         0.5821892
# 7   2019-12-30      N_G204R       6691624 N      G204R         0.5764110
# 8   2019-12-30      Spike_P681H   6555302 Spike  P681H         0.5646683
# 9   2019-12-30      Spike_N501Y   6279437 Spike  N501Y         0.5409056
# 10  2019-12-30      Spike_H655Y   5601471 Spike  H655Y         0.4825061
# 11  2019-12-30      Spike_L452R   5505085 Spike  L452R         0.4742035
# 12  2020-01-01      Spike_N969K   5482415 Spike  N969K         0.4722507
# ...

# %%
DF.p.subs.geq1 <- filter(DF.p.subs, per_abundance > 1)
DF.p.subs.geq1
# Out:
#     collection_date aa_subs      counts   region mutation_name fraction
# 1   2019-12-24      Spike_D614G  11551573 Spike  D614G         0.9950430
# 2   2019-12-24      NSP12_P323L  11513173 NSP12  P323L         0.9917353
# 3   2019-12-26      Spike_T478K   9024745 Spike  T478K         0.7773841
# 4   2019-12-26      NSP4_T492I    8993496 NSP4   T492I         0.7746924
# 5   2019-12-30      Spike_G142D   7847034 Spike  G142D         0.6759371
# 6   2019-12-30      N_R203K       6758704 N      R203K         0.5821892
# 7   2019-12-30      N_G204R       6691624 N      G204R         0.5764110
# 8   2019-12-30      Spike_P681H   6555302 Spike  P681H         0.5646683
# 9   2019-12-30      Spike_N501Y   6279437 Spike  N501Y         0.5409056
# 10  2019-12-30      Spike_H655Y   5601471 Spike  H655Y         0.4825061
# 11  2019-12-30      Spike_L452R   5505085 Spike  L452R         0.4742035
# 12  2020-01-01      Spike_N969K   5482415 Spike  N969K         0.4722507
# ...

# %%
DF.p.subs.top100 <- DF.p.subs %>%
  arrange(desc(per_abundance)) %>%
  slice(1:100)
DF.p.subs.top100
# Out:
#     collection_date aa_subs      counts   region mutation_name fraction
# 1   2019-12-24      Spike_D614G  11551573 Spike  D614G         0.9950430
# 2   2019-12-24      NSP12_P323L  11513173 NSP12  P323L         0.9917353
# 3   2019-12-26      Spike_T478K   9024745 Spike  T478K         0.7773841
# 4   2019-12-26      NSP4_T492I    8993496 NSP4   T492I         0.7746924
# 5   2019-12-30      Spike_G142D   7847034 Spike  G142D         0.6759371
# 6   2019-12-30      N_R203K       6758704 N      R203K         0.5821892
# 7   2019-12-30      N_G204R       6691624 N      G204R         0.5764110
# 8   2019-12-30      Spike_P681H   6555302 Spike  P681H         0.5646683
# 9   2019-12-30      Spike_N501Y   6279437 Spike  N501Y         0.5409056
# 10  2019-12-30      Spike_H655Y   5601471 Spike  H655Y         0.4825061
# 11  2019-12-30      Spike_L452R   5505085 Spike  L452R         0.4742035
# 12  2020-01-01      Spike_N969K   5482415 Spike  N969K         0.4722507
# ...

# %%
scale_x_date(date_breaks = "1 week", 
                 date_labels = "%b %d, %Y",
                 limits = as.Date(c('2019-12-01','2023-05-31')))
# Out:
# <ScaleContinuousDate>
#  Range:
#  Limits: 1.82e+04 -- 1.95e+04

# %%
DF.p.subs.geqpt01
# Out:
#      collection_date aa_subs     counts   region mutation_name fraction
# 1    2019-12-24      Spike_D614G 11551573 Spike  D614G         0.9950430
# 2    2019-12-24      NSP12_P323L 11513173 NSP12  P323L         0.9917353
# 3    2019-12-26      Spike_T478K  9024745 Spike  T478K         0.7773841
# 4    2019-12-26      NSP4_T492I   8993496 NSP4   T492I         0.7746924
# 5    2019-12-30      Spike_G142D  7847034 Spike  G142D         0.6759371
# 6    2019-12-30      N_R203K      6758704 N      R203K         0.5821892
# 7    2019-12-30      N_G204R      6691624 N      G204R         0.5764110
# 8    2019-12-30      Spike_P681H  6555302 Spike  P681H         0.5646683
# 9    2019-12-30      Spike_N501Y  6279437 Spike  N501Y         0.5409056
# 10   2019-12-30      Spike_H655Y  5601471 Spike  H655Y         0.4825061
# 11   2019-12-30      Spike_L452R  5505085 Spike  L452R         0.4742035
# 12   2020-01-01      Spike_N969K  5482415 Spike  N969K         0.4722507
# ...

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux Server 7.9 (Maipo)
#
# Matrix products: default
# BLAS/LAPACK: /ahg/regevdata/projects/ICA_Lung/Nishant/conda/envs/scrna/lib/libopenblasp-r0.3.21.so
#
# locale:
# [1] C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] patchwork_1.1.2   lubridate_1.9.2   forcats_1.0.0     stringr_1.5.0
#  [5] dplyr_1.1.0       purrr_1.0.1       readr_2.1.4       tidyr_1.3.0
#  [9] tibble_3.2.0      ggplot2_3.4.2     tidyverse_2.0.0   data.table_1.14.8
# [13] jsonlite_1.8.4    formatR_1.14
#
# loaded via a namespace (and not attached):
#  [1] pillar_1.9.0     compiler_4.2.2   base64enc_0.1-3  tools_4.2.2
#  [5] digest_0.6.31    uuid_1.1-0       timechange_0.2.0 evaluate_0.21
#  [9] lifecycle_1.0.3  gtable_0.3.3     pkgconfig_2.0.3  rlang_1.1.1
# ...
